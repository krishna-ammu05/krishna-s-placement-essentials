# %% [markdown]
# quick sort

# %%
def quicksort(arr):
    if len(arr)<=1:
        return arr
    p=arr[0]
    l=[x for x in arr[1:] if x<=p]
    r=[x for x in arr[1:] if x>p]
    return quicksort(l)+[p]+quicksort(r)
quicksort([10,3,12,9,7,140])
# Out:
# [3, 7, 9, 10, 12, 140]

# %% [markdown]
# Bubble Sort

# %%
def bubble(arr):
    l=len(arr)
    for x in range(l-1):
        for j in range(l-x-1):
            if arr[j]>arr[j+1]:
                arr[j],arr[j+1]=arr[j+1],arr[j]
    return arr
bubble([10,3,12,9,1,70,140])
# Out:
# [1, 3, 9, 10, 12, 70, 140]

# %% [markdown]
# mergesort

# %%
def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    return merge(left, right)

def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])
    return result
merge_sort([10,3,12,9,7,140])
# Out:
# [3, 7, 9, 10, 12, 140]

# %% [markdown]
# insertion sort

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]         # Element to be placed
        j = i - 1

        # Move elements greater than key to one position ahead
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1

        # Place the key at correct position
        arr[j+1] = key

    return arr

# Example
arr = [10, 3, 12, 9, 7, 140]
print("Before sorting:", arr)
print("After sorting:", insertion_sort(arr))
# Out:
# Before sorting: [10, 3, 12, 9, 7, 140]
# After sorting: [3, 7, 9, 10, 12, 140]

# %% [markdown]
# Selection sort

# %%
def Selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min=i
        for j in range(i+1,n):
            if arr[min]>arr[j]:
                min=j
        arr[i],arr[min]=arr[min],arr[i]
    return arr
Selection_sort([10,3,12,9,7,140])
# Out:
# [3, 7, 9, 10, 12, 140]

# %% [markdown]
# Heapsort

# %%
def heapify(arr, n, i):
    largest = i          # assume root is largest
    left = 2 * i + 1     # left child
    right = 2 * i + 2    # right child

    # check if left child is larger
    if left < n and arr[left] > arr[largest]:
        largest = left

    # check if right child is larger
    if right < n and arr[right] > arr[largest]:
        largest = right

    # if root not largest, swap and heapify affected subtree
    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]
        heapify(arr, n, largest)


def heap_sort(arr):
    n = len(arr)

    # build max heap
    for i in range(n // 2 - 1, -1, -1):
        heapify(arr, n, i)

    # extract elements one by one
    for i in range(n - 1, 0, -1):
        arr[i], arr[0] = arr[0], arr[i]  # move current max to end
        heapify(arr, i, 0)               # fix the heap for reduced size

    return arr


# Example
arr = [10, 3, 12, 9, 7, 140]
print("Before sorting:", arr)
print("After sorting:", heap_sort(arr))
# Out:
# Before sorting: [10, 3, 12, 9, 7, 140]
# After sorting: [3, 7, 9, 10, 12, 140]
